# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('Funds 11.csv',index_col= 'Date')

# %%
df.head()
# Out:
#            AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# Date
# 4/17/2020            16.6991             2.5766             3.3116
# 4/24/2020            16.8738             2.5808             3.3167
# 1/5/2020             16.6996             2.5811             3.3174
# 8/5/2020             16.8233             2.5871             3.3203
# 5/15/2020            16.9853             2.5927             3.3325
#
#            BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# Date
# 4/17/2020            1275.83              10.69             107.95
# 4/24/2020            1276.46              10.69             107.95
# 1/5/2020             1276.78              10.68             107.58
# 8/5/2020             1278.59              10.71             107.58
# 5/15/2020            1279.82              10.68             107.58
#
#            BLUESPH BM Equity  ALPCRDA LX Equity  ALCONGP AB Equity  \
# Date
# 4/17/2020            1076.21             116.33             1.5334
# ...

# %%
df.tail()
# Out:
#            AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# Date
# 1/14/2022            22.6119             2.9513             3.7834
# 1/21/2022            22.5163             2.9610             3.7951
# 1/28/2022            22.5308             2.9577             3.7931
# 4/2/2022             22.6486             2.9558             3.7901
# 11/2/2022            22.5737             2.9707             3.8039
#
#            BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# Date
# 1/14/2022            1417.68              11.63             110.04
# 1/21/2022            1421.01              11.64             110.04
# 1/28/2022            1421.72              11.65             110.04
# 4/2/2022             1421.81              11.66             109.91
# 11/2/2022            1421.87              11.65             109.91
#
#            BLUESPH BM Equity  ALPCRDA LX Equity  ALCONGP AB Equity  \
# Date
# 1/14/2022            1200.45             138.56             1.7106
# ...

# %%
df.plot(figsize=(10, 7))
plt.title("Closing Price of Mutual Funds", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Converting into Return. Log of percentage change of all stocks in the list.

# %%
Ret= df.pct_change().apply(lambda x: np.log(1+x))
Ret.head()
# Out:
#            AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# Date
# 4/17/2020                NaN                NaN                NaN
# 4/24/2020           0.010407           0.001629           0.001539
# 1/5/2020           -0.010377           0.000116           0.000211
# 8/5/2020            0.007380           0.002322           0.000874
# 5/15/2020           0.009583           0.002162           0.003668
#
#            BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# Date
# 4/17/2020                NaN                NaN                NaN
# 4/24/2020           0.000494           0.000000           0.000000
# 1/5/2020            0.000251          -0.000936          -0.003433
# 8/5/2020            0.001417           0.002805           0.000000
# 5/15/2020           0.000962          -0.002805           0.000000
#
#            BLUESPH BM Equity  ALPCRDA LX Equity  ALCONGP AB Equity  \
# Date
# 4/17/2020                NaN                NaN                NaN
# ...

# %%
Ret_df = Ret.iloc[1:5]

# %%
Ret_df.head()
# Out:
#            AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# Date
# 4/24/2020           0.010407           0.001629           0.001539
# 1/5/2020           -0.010377           0.000116           0.000211
# 8/5/2020            0.007380           0.002322           0.000874
# 5/15/2020           0.009583           0.002162           0.003668
#
#            BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# Date
# 4/24/2020           0.000494           0.000000           0.000000
# 1/5/2020            0.000251          -0.000936          -0.003433
# 8/5/2020            0.001417           0.002805           0.000000
# 5/15/2020           0.000962          -0.002805           0.000000
#
#            BLUESPH BM Equity  ALPCRDA LX Equity  ALCONGP AB Equity  \
# Date
# 4/24/2020           0.000000           0.006170           0.000717
# 1/5/2020            0.009985          -0.002138          -0.002283
# 8/5/2020            0.000000          -0.000514           0.006381
# ...

# %%
Ret.plot(title='Stocks weekly returns',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Stocks weekly returns'}, xlabel='Date'>

# %% [markdown]
# ## Calculating the Mean, Standard Deviation and Other Stats

# %%
Ann_Ret = Ret.mean()*52
print (Ann_Ret)
# Out:
# AIBALMA AB Equity    0.164994
# CCASORI MK Equity    0.077905
# CCASLTF MK Equity    0.075863
# BBFTOP3 KY Equity    0.059322
# CRLCBUU LX Equity    0.047072
# GMFDEBI LE Equity    0.009849
# BLUESPH BM Equity    0.056085
# ALPCRDA LX Equity    0.091994
# ALCONGP AB Equity    0.051767
# UBSFLBI LX Equity    0.022493
# dtype: float64

# %%
Ann_Risk = Ret.std()*(52)**(0.5)
print(Ann_Risk)
# Out:
# AIBALMA AB Equity    0.052010
# CCASORI MK Equity    0.016388
# CCASLTF MK Equity    0.016577
# BBFTOP3 KY Equity    0.011316
# CRLCBUU LX Equity    0.017065
# GMFDEBI LE Equity    0.005989
# BLUESPH BM Equity    0.046774
# ALPCRDA LX Equity    0.027841
# ALCONGP AB Equity    0.043235
# UBSFLBI LX Equity    0.013572
# dtype: float64

# %%
Ret_Risk = (Ann_Ret/Ann_Risk)
print(Ret_Risk)
# Out:
# AIBALMA AB Equity    3.172365
# CCASORI MK Equity    4.753824
# CCASLTF MK Equity    4.576345
# BBFTOP3 KY Equity    5.242223
# CRLCBUU LX Equity    2.758347
# GMFDEBI LE Equity    1.644473
# BLUESPH BM Equity    1.199068
# ALPCRDA LX Equity    3.304219
# ALCONGP AB Equity    1.197332
# UBSFLBI LX Equity    1.657342
# dtype: float64

# %%
x=Ann_Risk
y=Ann_Ret
plt.ylabel('Return', fontsize=14)
plt.xlabel('Risk', fontsize=14)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Calculating the Correlation and Covariance

# %%
Ret_Corr = Ret.corr()
print(Ret_Corr)
# Out:
#                    AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# AIBALMA AB Equity           1.000000           0.272233           0.184235
# CCASORI MK Equity           0.272233           1.000000           0.611575
# CCASLTF MK Equity           0.184235           0.611575           1.000000
# BBFTOP3 KY Equity          -0.000618           0.012781          -0.120390
# CRLCBUU LX Equity           0.016609           0.089729           0.060093
# GMFDEBI LE Equity           0.092952          -0.174179          -0.117151
# BLUESPH BM Equity          -0.031434          -0.130214          -0.053352
# ALPCRDA LX Equity           0.193055          -0.012737           0.051932
# ALCONGP AB Equity           0.395149           0.234938           0.170713
# UBSFLBI LX Equity           0.364420           0.253114           0.163266
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(Ret_Corr)
# Out:
# <AxesSubplot:>

# %%
Ret_Covar = Ret.cov()
print(Ret_Covar)
# Out:
#                    AIBALMA AB Equity  CCASORI MK Equity  CCASLTF MK Equity  \
# AIBALMA AB Equity       5.201934e-05       4.462164e-06       3.054655e-06
# CCASORI MK Equity       4.462164e-06       5.164686e-06       3.195064e-06
# CCASLTF MK Equity       3.054655e-06       3.195064e-06       5.284649e-06
# BBFTOP3 KY Equity      -6.997817e-09       4.558075e-08      -4.343028e-07
# CRLCBUU LX Equity       2.834879e-07       4.825812e-07       3.269214e-07
# GMFDEBI LE Equity       5.568143e-07      -3.287675e-07      -2.236784e-07
# BLUESPH BM Equity      -1.470577e-06      -1.919477e-06      -7.955450e-07
# ALPCRDA LX Equity       5.375880e-06      -1.117566e-07       4.609280e-07
# ALCONGP AB Equity       1.708763e-05       3.201214e-06       2.352947e-06
# UBSFLBI LX Equity       4.946667e-06       1.082597e-06       7.063697e-07
#
#                    BBFTOP3 KY Equity  CRLCBUU LX Equity  GMFDEBI LE Equity  \
# ...

# %% [markdown]
# ## Createing Portfolio

# %%
w = {'AIBALMA AB Equity':0.10, 'CCASORI MK Equity':0.10, 'CCASLTF MK Equity':0.10, 'BBFTOP3 KY Equity':0.10, 'CRLCBUU LX Equity':0.10, 'GMFDEBI LE Equity':0.10, 'BLUESPH BM Equity':0.10, 'ALPCRDA LX Equity':0.10, 'ALCONGP AB Equity':0.10, 'UBSFLBI LX Equity':0.10} 
port_var = Ret_Covar.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 2.8982693322651717e-06
# 0.00015071000527778892

# %%
Ann_port_std
# Out:
# 0.012276400338771497

# %%
w = [0.10,0.10,0.10,0.10,0.10,0.10,0.10,0.10,0.10,0.10]
port_er = (w*Ann_Ret).sum()
port_er
# Out:
# 0.06573437279772826

# %%
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(52))
ann_sd
# Out:
# AIBALMA AB Equity    0.052010
# CCASORI MK Equity    0.016388
# CCASLTF MK Equity    0.016577
# BBFTOP3 KY Equity    0.011316
# CRLCBUU LX Equity    0.017065
# GMFDEBI LE Equity    0.005989
# BLUESPH BM Equity    0.046774
# ALPCRDA LX Equity    0.027841
# ALCONGP AB Equity    0.043235
# UBSFLBI LX Equity    0.013572
# dtype: float64

# %%
assets = pd.concat([Ann_Ret,Ann_Risk,Ret_Risk], axis=1)
assets.columns = ['Ann Returns', 'Ann Risk', 'Ret per unit Risk']
assets
# Out:
#                    Ann Returns  Ann Risk  Ret per unit Risk
# AIBALMA AB Equity     0.164994  0.052010           3.172365
# CCASORI MK Equity     0.077905  0.016388           4.753824
# CCASLTF MK Equity     0.075863  0.016577           4.576345
# BBFTOP3 KY Equity     0.059322  0.011316           5.242223
# CRLCBUU LX Equity     0.047072  0.017065           2.758347
# GMFDEBI LE Equity     0.009849  0.005989           1.644473
# BLUESPH BM Equity     0.056085  0.046774           1.199068
# ALPCRDA LX Equity     0.091994  0.027841           3.304219
# ALCONGP AB Equity     0.051767  0.043235           1.197332
# UBSFLBI LX Equity     0.022493  0.013572           1.657342

# %% [markdown]
# To plot the graph of efficient frontier, we need to run a loop. In each iteration, the loop considers different weights for assets and calculates the return and risk of that particular portfolio combination.
# We run this loop a 100000 times.
# To get random numbers for weights, we use the np.random.random() function. As the sum of weights must be 1, weights are divided by their cumulative sum.

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(df.columns)
num_portfolios = 100000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights,Ann_Ret) 
    p_ret.append(returns)
    var = Ret_Covar.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Risk':p_vol}
for counter, symbol in enumerate(df.columns.tolist()):

    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 100000 portfolios created
# Out:
#     Returns      Risk  AIBALMA AB Equity weight  CCASORI MK Equity weight  \
# 0  0.071070  0.013697                  0.119974                  0.134348
# 1  0.056375  0.013389                  0.007438                  0.114353
# 2  0.054362  0.009969                  0.001254                  0.228826
# 3  0.058448  0.011302                  0.066984                  0.053907
# 4  0.065835  0.018363                  0.087872                  0.092616
#
#    CCASLTF MK Equity weight  BBFTOP3 KY Equity weight  \
# 0                  0.143460                  0.027603
# 1                  0.100986                  0.030671
# 2                  0.162391                  0.073177
# 3                  0.028451                  0.120212
# 4                  0.053848                  0.137952
#
#    CRLCBUU LX Equity weight  GMFDEBI LE Equity weight  \
# 0                  0.141631                  0.055534
# 1                  0.100487                  0.082841
# ...

# %% [markdown]
# Plotting the Efficient Frontier

# %%
portfolios.plot.scatter(x='Risk', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Risk'].idxmin()]
min_vol_port
# Out:
# Returns                     0.046598
# Risk                        0.006197
# AIBALMA AB Equity weight    0.015442
# CCASORI MK Equity weight    0.008694
# CCASLTF MK Equity weight    0.188483
# BBFTOP3 KY Equity weight    0.183103
# CRLCBUU LX Equity weight    0.076742
# GMFDEBI LE Equity weight    0.258209
# BLUESPH BM Equity weight    0.005910
# ALPCRDA LX Equity weight    0.081079
# ALCONGP AB Equity weight    0.005622
# UBSFLBI LX Equity weight    0.176716
# Name: 7833, dtype: float64

# %%
plt.subplots(figsize=[6,5])
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %% [markdown]
# Sharpe Ratio
# The ratio is the average return earned in excess of the risk-free rate per unit of volatility or total risk. Volatility is a measure of the price fluctuations of an asset or portfolio. The risk-free rate of return is the return on an investment with zero risk, meaning it’s the return investors could expect for taking no risk.

# %% [markdown]
# ## Finding the optimal portfolio

# %% [markdown]
# An optimal risky portfolio can be considered as one that has highest Sharpe ratio.

# %%
rf = 0.05 
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Risk']).idxmax()]
optimal_risky_port
# Out:
# Returns                     0.083673
# Risk                        0.012231
# AIBALMA AB Equity weight    0.077764
# CCASORI MK Equity weight    0.166989
# CCASLTF MK Equity weight    0.254165
# BBFTOP3 KY Equity weight    0.162347
# CRLCBUU LX Equity weight    0.023547
# GMFDEBI LE Equity weight    0.005680
# BLUESPH BM Equity weight    0.016936
# ALPCRDA LX Equity weight    0.289927
# ALCONGP AB Equity weight    0.002593
# UBSFLBI LX Equity weight    0.000052
# Name: 11670, dtype: float64

# %%
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
